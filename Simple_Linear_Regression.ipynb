# %% [markdown]
# <a href="https://colab.research.google.com/github/Saptasindhu07/Linear-Regression/blob/main/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-67331e9a-182e-4343-8abc-3c6d45b28c84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67331e9a-182e-4343-8abc-3c6d45b28c84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data= pd.read_csv('iq_marks_dataset2.csv')
data.head()
# Out:
#     IQ  Marks
# 0   91  66.32
# 1  106  74.12
# 2   92  67.45
# 3  127  84.78
# 4  108  75.23

# %%
plt.scatter(x=data['IQ'],y=data['Marks'],color='red',alpha=0.8,s=50)
plt.show()

# %%
data['IQ'].max()
# Out:
# 250

# %%
data[data['Marks']==100]
# Out:
#       IQ  Marks
# 90   170  100.0
# 91   171  100.0
# 92   172  100.0
# 94   173  100.0
# 95   174  100.0
# ..   ...    ...
# 363  246  100.0
# 364  247  100.0
# 365  248  100.0
# 366  249  100.0
# 367  250  100.0
#
# [135 rows x 2 columns]

# %%
data['IQ'].corr(data['Marks'])
# Out:
# np.float64(0.9461635072030333)

# %% [markdown]
# **SUPER HIGH CORRELATION WOHOOOOO!**

# %%
data.corr()
# Out:
#              IQ     Marks
# IQ     1.000000  0.946164
# Marks  0.946164  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IQ      449 non-null    int64
#  1   Marks   449 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 7.1 KB

# %%
X=data[['IQ']]
X.head()
# Out:
#     IQ
# 0   91
# 1  106
# 2   92
# 3  127
# 4  108
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['IQ'].plot(kind='hist', bins=20, title='IQ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['IQ'].plot(kind='line', figsize=(8, 4), title='IQ')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
y=data['Marks']
y.head()
# Out:
# 0    66.32
# 1    74.12
# 2    67.45
# 3    84.78
# 4    75.23
# Name: Marks, dtype: float64

# %% [markdown]
# **Train-Test Split**

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30)

# %%
X_train.shape
# Out:
# (314, 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %% [markdown]
# **APPLYING LINEAR REGRESSION**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([14.51091859])

# %%
lr.intercept_
# Out:
# np.float64(82.90570063694267)

# %% [markdown]
# **Let's draw the line now !!**

# %%
plt.scatter(X_train, y_train, color="blue",s=10)
plt.plot(X_train, lr.predict(X_train))

# %%
y_pred= lr.predict(X_test)

# %% [markdown]
# **TIME FOR SOME PERFORMANCE METRICS**

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error

# %%
mse=mean_squared_error(y_pred,y_test)
mae=mean_absolute_error(y_pred,y_test)
rmse=root_mean_squared_error(y_pred,y_test)

# %%
mse
# Out:
# 29.336039443680885

# %%
mae
# Out:
# 4.258582649151933

# %%
rmse
# Out:
# 5.416275421697173

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8711583759698164
